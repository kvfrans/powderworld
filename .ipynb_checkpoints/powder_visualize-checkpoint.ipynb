# %%
import sys
if 'ipykernel_launcher.py' in sys.argv[0]:
    print("Launched in Jupyter")
    # %load_ext autoreload
    # %autoreload 2

from powderworld import PowderWorld, PowderWorldRenderer
import powder_dists
import torch
import numpy as np
from IPython import display as ipythondisplay
import matplotlib.pyplot as plt

device = 'cuda'
pw = PowderWorld(device)
pwr = PowderWorldRenderer(device)


def show_row(world, name='dist', size=4):
    imgs = [pwr.render(world[x:x+1]) for x in range(size)]
    fig = plt.figure(figsize=(16*size,16))
    axarr = fig.subplots(1, size)
    for b in range(size):
        axarr[b].imshow(imgs[b])
        axarr[b].get_xaxis().set_visible(False)
        axarr[b].get_yaxis().set_visible(False)
    del imgs
    fig.show()
    fig.savefig('figs/{}.png'.format(name))
    plt.show()
    del fig
    
world = torch.zeros((4, pw.NUM_CHANNEL, 64, 64), dtype=torch.float32, device=device)
for b in range(4):
    powder_dists.make_test(pw, world[b:b+1], b)
show_row(world)
for t in range(64):
    world = pw(world)
show_row(world)
    
# world = torch.zeros((4, pw.NUM_CHANNEL, 64, 64), dtype=torch.float32, device=device)
# for b in range(4):
#     powder_dists.make_world(pw, world[b:b+1], num_lines=5, num_circles=0, num_squares=0)
# show_row(world)

# world = torch.zeros((4, pw.NUM_CHANNEL, 64, 64), dtype=torch.float32, device=device)
# for b in range(4):
#     powder_dists.make_world(pw, world[b:b+1], num_lines=0, num_circles=5, num_squares=0)
# show_row(world)

# world = torch.zeros((4, pw.NUM_CHANNEL, 64, 64), dtype=torch.float32, device=device)
# for b in range(4):
#     powder_dists.make_world(pw, world[b:b+1], num_lines=0, num_circles=0, num_squares=5)
# show_row(world)

# world = torch.zeros((4, pw.NUM_CHANNEL, 64, 64), dtype=torch.float32, device=device)
# for b in range(4):
#     powder_dists.make_world(pw, world[b:b+1], num_tasks=2)
# show_row(world)

# world = torch.zeros((4, pw.NUM_CHANNEL, 64, 64), dtype=torch.float32, device=device)
# for b in range(4):
#     powder_dists.make_world(pw, world[b:b+1], num_circles=5)
# show_row(world)

# world = torch.zeros((4, pw.NUM_CHANNEL, 64, 64), dtype=torch.float32, device=device)
# for b in range(4):
#     powder_dists.make_world(pw, world[b:b+1], num_circles=5, do_background=True)
# show_row(world)

# world = torch.zeros((4, pw.NUM_CHANNEL, 64, 64), dtype=torch.float32, device=device)
# for b in range(4):
#     powder_dists.make_rl_world(pw, world[b:b+1], num_circles=5, has_empty_path=True)
# show_row(world)
# Out:
# Launched in Jupyter
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# world = torch.zeros((4, pw.NUM_CHANNEL, 64, 64), dtype=torch.float32, device=device)
# for b in range(4):
#     powder_dists.make_test(pw, world[b:b+1], b)
# show_row(world)
# for t in range(64):
#     world = pw(world)
# show_row(world)

# world = torch.zeros((4, pw.NUM_CHANNEL, 64, 64), dtype=torch.float32, device=device)
# for b in range(4):
#     powder_dists.make_test(pw, world[b:b+1], b+4)
# show_row(world)
# for t in range(32):
#     world = pw(world)
# show_row(world)

# world = torch.zeros((4, pw.NUM_CHANNEL, 64, 64), dtype=torch.float32, device=device)
# for b in range(4):
#     powder_dists.make_rl_test(pw, world[b:b+1], b)
# show_row(world)
# for t in range(32):
#     world = pw(world)
# show_row(world)

# world = torch.zeros((4, pw.NUM_CHANNEL, 64, 64), dtype=torch.float32, device=device)
# for b in range(4):
#     powder_dists.make_rl_test(pw, world[b:b+1], b+4)
# show_row(world)
# for t in range(32):
#     world = pw(world)
# show_row(world)
# Out:
# torch.Size([1, 20, 64, 64])
# torch.Size([1, 20, 64, 64])
# torch.Size([1, 20, 64, 64])
# torch.Size([1, 20, 64, 64])
# torch.Size([1, 20, 64, 64])
# torch.Size([1, 20, 64, 64])
# torch.Size([1, 20, 64, 64])
# torch.Size([1, 20, 64, 64])

# %%
all_elems = ['empty', 'sand', 'water', 'wall', 'plant', 'fire', 'wood', 'ice', 'lava', 'dust', 'cloner', 'gas', 'acid', 'stone']
# world = torch.zeros((4, pw.NUM_CHANNEL, 64, 64), dtype=torch.float32, device=device)
# powder_dists.make_world(pw, world[0:1], elems=all_elems, num_lines=0, num_circles=5, num_squares=0)
# powder_dists.make_world(pw, world[1:2], elems=all_elems, num_lines=0, num_circles=0, num_squares=5)
# powder_dists.make_world(pw, world[2:3], elems=all_elems, num_lines=0, num_circles=5, num_squares=5)
# powder_dists.make_world(pw, world[3:4], elems=all_elems, num_lines=5, num_circles=5, num_squares=5)
# show_row(world, 'dist_complexity')
# for t in range(32):
#     world = pw(world)
# show_row(world, 'dist_complexity_after')

# world = torch.zeros((4, pw.NUM_CHANNEL, 64, 64), dtype=torch.float32, device=device)
# powder_dists.make_world(pw, world[0:1], elems=all_elems, num_lines=2, num_circles=0, do_background=False)
# powder_dists.make_world(pw, world[1:2], elems=all_elems, num_lines=8, num_circles=0, do_background=False)
# powder_dists.make_world(pw, world[2:3], elems=all_elems, num_lines=16, num_circles=0, do_background=False)
# powder_dists.make_world(pw, world[3:4], elems=all_elems, num_lines=32, num_circles=0, do_background=False)
# show_row(world, 'dist_lines')
# for t in range(32):
#     world = pw(world)
# show_row(world, 'dist_lines_after')

# world = torch.zeros((8, pw.NUM_CHANNEL, 64, 64), dtype=torch.float32, device=device)
# for b in range(8):
#     powder_dists.make_test(pw, world[b:b+1], b)
# show_row(world, 'dist_test', 8)
# for t in range(16):
#     world = pw(world)
# show_row(world, 'dist_test_after', 8)

# world = torch.zeros((1, pw.NUM_CHANNEL, 64, 64), dtype=torch.float32, device=device)
# powder_dists.make_world(pw, world, elems=all_elems, num_lines=5, num_circles=0, do_background=False)
# world_save = torch.zeros((8, pw.NUM_CHANNEL, 64, 64), dtype=torch.float32, device=device)
# for i in range(4):
#     world_save[i] = world.clone()
#     for t in range(16):
#         world = pw(world)
# show_row(world_save, 'dist_tasknum')

# world = torch.zeros((4, pw.NUM_CHANNEL, 64, 64), dtype=torch.float32, device=device)
# powder_dists.make_world(pw, world[0:1], elems=all_elems[:2], num_lines=5, num_circles=5, num_squares=5, num_tasks=20)
# powder_dists.make_world(pw, world[1:2], elems=all_elems[:4], num_lines=5, num_circles=5, num_squares=5, num_tasks=20)
# powder_dists.make_world(pw, world[2:3], elems=all_elems[:-3], num_lines=5, num_circles=5, num_squares=5, num_tasks=20)
# powder_dists.make_world(pw, world[3:4], elems=all_elems[-3:], num_lines=5, num_circles=5, num_squares=5, num_tasks=20)
# show_row(world, 'dist_elems')
# for t in range(32):
#     world = pw(world)
# show_row(world, 'dist_elems_after')

# world = torch.zeros((4, pw.NUM_CHANNEL, 64, 64), dtype=torch.float32, device=device)
# powder_dists.make_world(pw, world[0:1], elems=all_elems, num_lines=2, num_circles=0, do_background=False)
# powder_dists.make_world(pw, world[1:2], elems=all_elems, num_lines=8, num_circles=0, do_background=False)
# powder_dists.make_world(pw, world[2:3], elems=all_elems, num_lines=16, num_circles=0, do_background=False)
# powder_dists.make_world(pw, world[3:4], elems=all_elems, num_lines=32, num_circles=0, do_background=False)
# show_row(world, 'dist_lines')
# for t in range(32):
#     world = pw(world)
# show_row(world, 'dist_lines_after')

# world = torch.zeros((8, pw.NUM_CHANNEL, 64, 64), dtype=torch.float32, device=device)
# for b in range(8):
#     powder_dists.make_rl_test(pw, world[b:b+1], b)
# show_row(world, 'dist_rl_test', 8)
# for t in range(32):
#     world = pw(world)
# show_row(world, 'dist_rl_test_after', 8)

# world = torch.zeros((4, pw.NUM_CHANNEL, 64, 64), dtype=torch.float32, device=device)
# powder_dists.make_world(pw, world[0:1], elems=all_elems, num_lines=5, num_circles=2, num_squares=0)
# powder_dists.make_world(pw, world[1:2], elems=all_elems, num_lines=5, num_circles=2, num_squares=0)
# powder_dists.make_world(pw, world[2:3], elems=all_elems, num_lines=5, num_circles=2, num_squares=0)
# powder_dists.make_world(pw, world[3:4], elems=all_elems, num_lines=5, num_circles=2, num_squares=0)
# show_row(world, 'dist_bench')
# for t in range(32):
#     world = pw(world)
# show_row(world, 'dist_bench_after')
